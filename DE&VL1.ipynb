# %%
import pandas as pd
import numpy as np

df = pd.read_csv('student.csv')
df.head()
# Out:
#   Unnamed: 0   Name  height  weight  sex       bdate    city major
# 0   s1234567  Peter   175.0   70.45    1   1980/4/30  Tainan  CSIE
# 1   e1234567   Mary   163.0   55.00    2  1981/12/21  Taipei    EE
# 2   f1357689   John   180.4   80.30    1   1980/5/30  Tainan  Stat
# 3   e1374659  Keven   182.5   77.60    1  1980/11/19  Taipei    EE
# 4   s7758347   JoJo   170.3   50.30    2   1980/1/27  Taipei  CSIE

# %%
df.tail()
# Out:
#   Unnamed: 0    Name  height  weight  sex       bdate       city major
# 2   f1357689    John   180.4    80.3    1   1980/5/30     Tainan  Stat
# 3   e1374659   Keven   182.5    77.6    1  1980/11/19     Taipei    EE
# 4   s7758347    JoJo   170.3    50.3    2   1980/1/27     Taipei  CSIE
# 5   s1334987   Emily   168.5    53.6    2  1982/10/13  Kaohsiung  CSIE
# 6   e1384726  Ubuntu   177.0    68.3    1    1981/7/6  Kaohsiung    EE

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'height', 'weight', 'sex', 'bdate', 'city',
#        'major'],
#       dtype='object')

# %%
df.Name
# Out:
# 0     Peter
# 1      Mary
# 2      John
# 3     Keven
# 4      JoJo
# 5     Emily
# 6    Ubuntu
# Name: Name, dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
df[['Name','major','height']]
# Out:
#      Name major  height
# 0   Peter  CSIE   175.0
# 1    Mary    EE   163.0
# 2    John  Stat   180.4
# 3   Keven    EE   182.5
# 4    JoJo  CSIE   170.3
# 5   Emily  CSIE   168.5
# 6  Ubuntu    EE   177.0

# %%
df['height'].max()
# Out:
# 182.5

# %%
df.describe()
# Out:
#            height     weight       sex
# count    7.000000   7.000000  7.000000
# mean   173.814286  65.078571  1.428571
# std      6.927103  12.106811  0.534522
# min    163.000000  50.300000  1.000000
# 25%    169.400000  54.300000  1.000000
# 50%    175.000000  68.300000  1.000000
# 75%    178.700000  74.025000  2.000000
# max    182.500000  80.300000  2.000000

# %%
df[df.height==df.height.max()]
# Out:
#   Unnamed: 0   Name  height  weight  sex       bdate    city major
# 3   e1374659  Keven   182.5    77.6    1  1980/11/19  Taipei    EE

# %%
xy=pd.read_excel("pass.xls","Sheet1")
xy
# Out:
#     YEAR       Y      W       R      L      K
# 0   1948   1.214  0.243  0.1454  1.415  0.612
# 1   1949   1.354  0.260  0.2181  1.384  0.559
# 2   1950   1.569  0.278  0.3157  1.388  0.573
# 3   1951   1.948  0.297  0.3940  1.550  0.564
# 4   1952   2.265  0.310  0.3559  1.802  0.574
# 5   1953   2.731  0.322  0.3593  1.926  0.711
# 6   1954   3.025  0.335  0.4025  1.964  0.776
# 7   1955   3.562  0.350  0.3961  2.116  0.827
# 8   1956   3.979  0.361  0.3822  2.435  0.800
# 9   1957   4.420  0.379  0.3045  2.707  0.921
# 10  1958   4.563  0.391  0.3284  2.706  1.067
# 11  1959   5.385  0.426  0.3856  2.846  1.083
# 12  1960   5.554  0.441  0.3193  3.089  1.481
# 13  1961   5.465  0.460  0.3079  3.122  1.736
# 14  1962   5.825  0.485  0.3783  3.184  1.926
# 15  1963   6.876  0.506  0.4180  3.263  2.041
# 16  1964   7.823  0.538  0.5163  3.412  1.997
# 17  1965   9.120  0.564  0.5879  3.623  2.257
# 18  1966  10.512  0.586  0.5369  4.074  2.742
# ...

# %%
df = pd.read_csv('student.csv',header=None,names=['Name','major','height']) # if no header is there then we use this
df

# %%
df = pd.read_csv('student.csv', nrows=2)  # for number of rows
df

# %%
new_df = df.fillna(0)#fill the missing cell with 0
new_df

# %%
new_df = df.fillna({
    'Name':0,
    'major':0,
    'height':0
})
new_df # for specific value in cell

# %%
new_df=df.dropna()
new_df# it will delete all the missing cell (like entire row)
